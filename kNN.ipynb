# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajan0110/AILabNewRepo/blob/main/kNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from collections import Counter

class KNN:
    def __init__(self, k=3):
        self.k = k

    # Train the model (store training data)
    def fit(self, X_train, y_train):
        self.X_train = X_train
        self.y_train = y_train

    def predict_point(self, x):

        distances = np.linalg.norm(self.X_train - x, axis=1)

        k_indices = distances.argsort()[:self.k]

        k_labels = self.y_train[k_indices]

        most_common = Counter(k_labels).most_common(1)
        return most_common[0][0]

    def predict(self, X_test):
        return np.array([self.predict_point(x) for x in X_test])



if __name__ == "__main__":

    X_train = np.array([[1, 2],
                        [2, 3],
                        [3, 3],
                        [6, 5],
                        [7, 7],
                        [8, 6]])
    y_train = np.array([0, 0, 0, 1, 1, 1])

    X_test = np.array([[2, 2],
                       [7, 5]])

    k = 3
    model = KNN(k=k)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test)
    for i, point in enumerate(X_test):
        print(f"Point {point} -> Predicted Class: {predictions[i]}")
# Out:
# Point [2 2] -> Predicted Class: 0
# Point [7 5] -> Predicted Class: 1
